# %% [markdown]
# ## importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=6*np.random.rand(100, 1)-3
y=0.5 * x**2 + 1.5*x +2 +np.random.rand(100, 1)
#quadratic equation is used - y=0.5x^2 +1.5x +2 + outliers
plt.scatter(x,y, color='green')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial Regression Data')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#lets implement simple linear regression
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test, model.predict(x_test))
print(score)
# Out:
# 0.8575699163522426

# %%
#lets visualize the linear regression line
plt.plot(x_train, model.predict(x_train), color='red')
plt.scatter(x_train, y_train, color='green')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression')
plt.show()

# %%
#lets apply polinomial transformation
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2, include_bias=True)
x_train_poly=poly.fit_transform(x_train)
x_test_poly=poly.transform(x_test)

# %%
x_train_poly
# Out:
# array([[ 1.00000000e+00,  2.38047331e+00,  5.66665317e+00],
#        [ 1.00000000e+00,  5.35933332e-01,  2.87224536e-01],
#        [ 1.00000000e+00, -1.82343667e+00,  3.32492127e+00],
#        [ 1.00000000e+00, -1.30561595e+00,  1.70463301e+00],
#        [ 1.00000000e+00,  3.12078216e-01,  9.73928131e-02],
#        [ 1.00000000e+00,  4.60915738e-01,  2.12443318e-01],
#        [ 1.00000000e+00, -1.64452413e+00,  2.70445963e+00],
#        [ 1.00000000e+00,  2.80744436e+00,  7.88174386e+00],
#        [ 1.00000000e+00, -1.18709217e+00,  1.40918782e+00],
#        [ 1.00000000e+00,  6.47338640e-01,  4.19047315e-01],
#        [ 1.00000000e+00, -7.62223534e-01,  5.80984716e-01],
#        [ 1.00000000e+00, -9.87598541e-01,  9.75350878e-01],
#        [ 1.00000000e+00,  9.43576630e-01,  8.90336858e-01],
#        [ 1.00000000e+00,  1.93698676e+00,  3.75191770e+00],
#        [ 1.00000000e+00, -2.94534324e+00,  8.67504679e+00],
#        [ 1.00000000e+00,  2.68040657e+00,  7.18457941e+00],
# ...

# %%
x_test_poly
# Out:
# array([[ 1.        ,  1.27881848,  1.6353767 ],
#        [ 1.        , -0.8875246 ,  0.78769991],
#        [ 1.        , -1.63509208,  2.67352612],
#        [ 1.        ,  0.57424129,  0.32975306],
#        [ 1.        , -1.6815752 ,  2.82769514],
#        [ 1.        ,  0.21484904,  0.04616011],
#        [ 1.        ,  1.30602109,  1.70569109],
#        [ 1.        , -2.17416523,  4.72699445],
#        [ 1.        ,  2.73399279,  7.47471658],
#        [ 1.        ,  0.5346277 ,  0.28582678],
#        [ 1.        ,  2.15214319,  4.6317203 ],
#        [ 1.        , -1.59992979,  2.55977532],
#        [ 1.        ,  2.38406872,  5.68378366],
#        [ 1.        , -0.5564454 ,  0.30963148],
#        [ 1.        , -0.46751841,  0.21857346],
#        [ 1.        , -1.87115408,  3.5012176 ],
#        [ 1.        ,  2.78658672,  7.76506554],
#        [ 1.        ,  1.38327195,  1.91344128],
#        [ 1.        ,  2.50217031,  6.26085625],
# ...

# %%
model_1=LinearRegression()
model_1.fit(x_train_poly, y_train)
y_pred_poly=model_1.predict(x_test_poly)
r2score_poly=r2_score(y_test, y_pred_poly)
print("R2 score for polynomial regression: ", r2score_poly)
# Out:
# R2 score for polynomial regression:  0.9928198296482859

# %%
print(model_1.coef_)
# Out:
# [[0.         1.49280465 0.51628534]]

# %%
print(model_1.intercept_)
# Out:
# [2.48867773]

# %%
plt.scatter(x_train, model_1.predict(x_train_poly), color='green')
plt.scatter(x_train, y_train, color='red')

# %%
# prediction of new dataset
x_new=np.linspace(-3,3,200).reshape(200, 1)
x_new_poly=poly.transform(x_new)
x_new_poly
# Out:
# array([[ 1.00000000e+00, -3.00000000e+00,  9.00000000e+00],
#        [ 1.00000000e+00, -2.96984925e+00,  8.82000455e+00],
#        [ 1.00000000e+00, -2.93969849e+00,  8.64182723e+00],
#        [ 1.00000000e+00, -2.90954774e+00,  8.46546804e+00],
#        [ 1.00000000e+00, -2.87939698e+00,  8.29092700e+00],
#        [ 1.00000000e+00, -2.84924623e+00,  8.11820409e+00],
#        [ 1.00000000e+00, -2.81909548e+00,  7.94729931e+00],
#        [ 1.00000000e+00, -2.78894472e+00,  7.77821267e+00],
#        [ 1.00000000e+00, -2.75879397e+00,  7.61094417e+00],
#        [ 1.00000000e+00, -2.72864322e+00,  7.44549380e+00],
#        [ 1.00000000e+00, -2.69849246e+00,  7.28186157e+00],
#        [ 1.00000000e+00, -2.66834171e+00,  7.12004747e+00],
#        [ 1.00000000e+00, -2.63819095e+00,  6.96005151e+00],
#        [ 1.00000000e+00, -2.60804020e+00,  6.80187369e+00],
#        [ 1.00000000e+00, -2.57788945e+00,  6.64551400e+00],
#        [ 1.00000000e+00, -2.54773869e+00,  6.49097245e+00],
# ...

# %%
y_new=model_1.predict(x_new_poly)
plt.plot(x_new, y_new, linewidth=2, label="predictions")
plt.scatter(x_train, y_train, color='green', label="training data")
plt.scatter(x_test, y_test, color='red', label="test data")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
